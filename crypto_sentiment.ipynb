# %%
import os
import pandas as pd
# %matplotlib inline
from newsapi import NewsApiClient

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# # News Headlines Sentiment
#
# Use the news api to pull the latest news articles for bitcoin and ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Read your api key environment variable
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_headlines = newsapi.get_everything(q="bitcoin AND Bitcoin",language="en",page_size=100,sort_by="relevancy")

# %%
# Fetch the Ethereum news articles
ethereum_headlines = newsapi.get_everything(q="ethereum", language="en")

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sentiments = []

for article in bitcoin_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        bitcoin_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
bitcoin_df = pd.DataFrame(bitcoin_sentiments)
bitcoin_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Bitcoin is going through a remarkably bad day....   -0.2944     0.074
# 1  After launching two cryptocurrency-oriented sm...    0.0000     0.000
# 2  Indias Supreme Court on Wednesday overturned c...   -0.5106     0.103
# 3  Our robot colleague Satoshi Nakaboto writes ab...    0.5070     0.068
# 4  Former Coinbase chief legal officer Brian Broo...    0.4939     0.085
#
#    negative  neutral
# 0     0.078    0.847
# 1     0.000    1.000
# 2     0.168    0.730
# 3     0.000    0.932
# 4     0.000    0.915

# %%
# Create the ethereum sentiment scores DataFrame
ethereum_sentiments = []

for article in ethereum_headlines["articles"]:
    try:
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        ethereum_sentiments.append({
            "text": text,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    

ethereum_df = pd.DataFrame(ethereum_sentiments)
ethereum_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Bitcoin is going through a remarkably bad day....   -0.2944     0.074
# 1  If a player picks up an item in an online vide...    0.0000     0.000
# 2  Coinbase Card, the Visa debit card that lets y...   -0.1027     0.000
# 3  When it comes to celebrities shilling shady in...    0.3182     0.112
# 4  The South Korean National Assembly passed new ...    0.4019     0.068
#
#    negative  neutral
# 0     0.078    0.847
# 1     0.000    1.000
# 2     0.035    0.965
# 3     0.066    0.822
# 4     0.000    0.932

# %%
# Describe the Bitcoin Sentiment
bitcoin_df.iloc[:, 1:5].describe()
# Out:
#         compound   positive   negative    neutral
# count  93.000000  93.000000  93.000000  93.000000
# mean    0.130571   0.080183   0.055097   0.864753
# std     0.522393   0.064745   0.067274   0.085471
# min    -0.933700   0.000000   0.000000   0.616000
# 25%    -0.340000   0.046000   0.000000   0.820000
# 50%     0.318200   0.068000   0.042000   0.882000
# 75%     0.507000   0.107000   0.095000   0.932000
# max     0.923100   0.331000   0.295000   1.000000

# %%
# Describe the Ethereum Sentiment
ethereum_df.iloc[:, 1:5].describe()
# Out:
#         compound   positive   negative    neutral
# count  19.000000  19.000000  19.000000  19.000000
# mean    0.165926   0.071053   0.041105   0.887895
# std     0.467050   0.060564   0.045282   0.060976
# min    -0.717400   0.000000   0.000000   0.762000
# 25%    -0.051350   0.022500   0.000000   0.843000
# 50%     0.340000   0.068000   0.035000   0.899000
# 75%     0.459300   0.101500   0.063000   0.930000
# max     0.895500   0.208000   0.133000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A:
#
# Q: Which coin had the highest compound score?
#
# A:
#
# Q. Which coin had the highest positive score?
#
# A:

# %% [markdown]
# ---

# %% [markdown]
# # Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word
# 2. Remove Punctuation
# 3. Remove Stopwords

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re
lemmatizer = WordNetLemmatizer()

# %%
# Expand the default stopwords list if necessary

# Expand the default stopwords list if necessary
sw_addon = {'chars'}

text = bitcoin_df.text[0]
regex = re.compile("[^a-zA-Z ]")
clean_text = regex.sub('', text)
sentence = sent_tokenize(clean_text)
words = []
for sent in sentence:
    word = word_tokenize(sent)
    words = words + word
words_lower = [word.lower() for word in words]
sw = set(stopwords.words('english'))
words_sw = [word for word in words_lower if word not in sw.union(sw_addon)]
tokens = [lemmatizer.lemmatize(word) for word in words_sw]

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation
    regex = re.compile("[^a-zA-Z ]")
    clean_text = regex.sub('', text)
    # Create a list of the words
    sentence = sent_tokenize(clean_text)
    words = []
    for sent in sentence:
        word = word_tokenize(sent)
        words = words + word    
    # Convert the words to lowercase
    words_lower = [word.lower() for word in words]    
    # Remove the stop words
    sw = set(stopwords.words('english'))
    words_sw = [word for word in words_lower if word not in sw.union(sw_addon)]
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words_sw]
    return tokens

# %%
# Create a new tokens column for bitcoin
bitcoin_df['tokens'] = [tokenizer(text) for text in bitcoin_df['text']]
bitcoin_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Bitcoin is going through a remarkably bad day....   -0.2944     0.074
# 1  After launching two cryptocurrency-oriented sm...    0.0000     0.000
# 2  Indias Supreme Court on Wednesday overturned c...   -0.5106     0.103
# 3  Our robot colleague Satoshi Nakaboto writes ab...    0.5070     0.068
# 4  Former Coinbase chief legal officer Brian Broo...    0.4939     0.085
#
#    negative  neutral                                             tokens
# 0     0.078    0.847  [bitcoin, going, remarkably, bad, day, turn, a...
# 1     0.000    1.000  [launching, two, cryptocurrencyoriented, smart...
# 2     0.168    0.730  [india, supreme, court, wednesday, overturnedc...
# 3     0.000    0.932  [robot, colleague, satoshi, nakaboto, writes, ...
# 4     0.000    0.915  [former, coinbase, chief, legal, officer, bria...

# %%
# Create a new tokens column for ethereum
ethereum_df['tokens'] = [tokenizer(text) for text in ethereum_df['text']]
ethereum_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  Bitcoin is going through a remarkably bad day....   -0.2944     0.074
# 1  If a player picks up an item in an online vide...    0.0000     0.000
# 2  Coinbase Card, the Visa debit card that lets y...   -0.1027     0.000
# 3  When it comes to celebrities shilling shady in...    0.3182     0.112
# 4  The South Korean National Assembly passed new ...    0.4019     0.068
#
#    negative  neutral                                             tokens
# 0     0.078    0.847  [bitcoin, going, remarkably, bad, day, turn, a...
# 1     0.000    1.000  [player, pick, item, online, video, game, owns...
# 2     0.035    0.965  [coinbase, card, visa, debit, card, let, spend...
# 3     0.066    0.822  [come, celebrity, shilling, shady, initial, co...
# 4     0.000    0.932  [south, korean, national, assembly, passed, ne...

# %% [markdown]
# ---

# %% [markdown]
# # NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
#Generate the Bitcoin N-grams where N=2
big_string = ' '.join(bitcoin_df['text'])
processed = tokenizer(big_string)
bigrams = ngrams(processed, n=2)
Counter(bigrams).most_common(10)
# Out:
# [(('satoshi', 'nakaboto'), 30),
#  (('robot', 'colleague'), 15),
#  (('colleague', 'satoshi'), 15),
#  (('nakaboto', 'writes'), 15),
#  (('writes', 'bitcoin'), 15),
#  (('every', 'fucking'), 15),
#  (('fucking', 'daywelcome'), 15),
#  (('daywelcome', 'another'), 15),
#  (('another', 'edition'), 15),
#  (('edition', 'bitcoin'), 15)]

# %%
# Generate the Ethereum N-grams where N=2
big_string = ' '.join(ethereum_df['text'])
processed = tokenizer(big_string)
bigrams = ngrams(processed, n=2)
Counter(bigrams).most_common(10)
# Out:
# [(('fell', 'first'), 3),
#  (('first', 'time'), 3),
#  (('debit', 'card'), 2),
#  (('reutersbitcoin', 'tanked'), 2),
#  (('tanked', 'thursday'), 2),
#  (('thursday', 'fell'), 2),
#  (('time', 'since'), 2),
#  (('since', 'may'), 2),
#  (('may', 'amid'), 2),
#  (('amid', 'larger'), 2)]

# %%
# Use the token_count function to generate the top 10 words from each coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Get the top 10 words for Bitcoin
big_string = ' '.join(bitcoin_df['text'])
processed = tokenizer(big_string)
token_count(processed)
# Out:
# [('bitcoin', 80),
#  ('satoshi', 30),
#  ('nakaboto', 30),
#  ('today', 21),
#  ('going', 18),
#  ('hour', 18),
#  ('btc', 18),
#  ('cryptocurrency', 18),
#  ('used', 18),
#  ('say', 18)]

# %%
# Get the top 10 words for Ethereum
big_string = ' '.join(ethereum_df['text'])
processed = tokenizer(big_string)
token_count(processed)
# Out:
# [('cryptocurrency', 8),
#  ('new', 7),
#  ('bitcoin', 5),
#  ('company', 5),
#  ('first', 5),
#  ('fell', 5),
#  ('ethereum', 5),
#  ('coinbase', 4),
#  ('thursday', 4),
#  ('selloff', 4)]

# %% [markdown]
# # Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
big_string = ' '.join(bitcoin_df['text'])
processed = tokenizer(big_string)
input_text = ' '.join(processed)
wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
big_string = ' '.join(ethereum_df['text'])
processed = tokenizer(big_string)
input_text = ' '.join(processed)
wc = WordCloud().generate(input_text)
plt.imshow(wc)

# %% [markdown]
# # Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both coins and visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Optional - download a language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Bitcoin NER

# %%
# Concatenate all of the bitcoin text together
article = ' '.join(bitcoin_df['text'])
article
# Out:
# 'Bitcoin is going through a remarkably bad day. It turns out all assets are having a rough month including cryptocurrencies. A couple of hours ago, the average price of BTC dropped by 15% in just 20 minutes.\r\nOn CoinGecko, 1 BTC was worth around $7,250 across … [+1146 chars] After launching two cryptocurrency-oriented smartphones, the HTC Exodus 1 and the Exodus 1s, the company is expanding the lineup with an entirely new device: a 5G router that can function as a full Bitcoin node.\xa0\r\nCalled the HTC Exodus 5G hub, the Android-bas… [+2230 chars] Indias Supreme Court on Wednesday overturned\xa0central banks two-year-old ban on cryptocurrency trading in the country in what many said was a historic verdict.\r\nThe Reserve Bank of India had imposed a ban on cryptocurrency trading in April 2018 that barred ban… [+1336 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Descartes used to say: Your heart must go … [+2896 chars] Former Coinbase chief legal officer Brian Brooks has been tapped as the chief operating officer and first deputy comptroller of the Office of the Comptroller of the Currency, beginning April 1, 2020.\r\nIn the role, Brooks will help the OCC in its mission of ch… [+1156 chars] The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges.\r\nIn a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Rousseau used to say: Success is just … [+2892 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Hegel used to say: Whip it, whip it, w… [+2889 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Bentham used to say: Fight the power!\r… [+3163 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Hannah Arendt used to say: Crack open … [+2601 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Marie Curie used to say: Talk to a str… [+2973 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Stephen Hawking used to say: Fight the… [+3054 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Nightingale used to say: Success is ju… [+3308 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of Bitcoin Today, where I, Satoshi Nakaboto, tell you whats been going on with Bitcoin in the past 24 hours. As Marie Curie used to say: Buy low, sell… [+2955 chars] Our robot colleague Satoshi Nakaboto writes about Bitcoin BTC every fucking day.\r\nWelcome to another edition of  ...

# %%
# Run the NER processor on all of the text
doc = nlp(article)
# Add a title to the document

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is going through a remarkably bad day. It turns out all assets are having a rough month including cryptocurrencies.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A couple of hours ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , the average price of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dropped by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just 20 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </br>On
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CoinGecko
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around $7,250
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  across … [+1146 chars] After launching
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cryptocurrency-oriented smartphones, the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTC Exodus 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  and the
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exodus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  1s, the company is expanding the lineup with an entirely new device: a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# G router that can function as a full
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>Called the
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTC Exodus 5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# G hub, the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android-bas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# … [+2230 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indias Supreme Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  overturned central banks
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two-year-old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Reserve Bank of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had imposed a ban on cryptocurrency trading in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  that barred ban… [+1336 chars] Our robot colleague
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Satoshi Nakaboto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  writes about
# <mark class="entity" style="backgrou

# %%
# List all Entities
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Bitcoin GPE
# A couple of hours ago TIME
# BTC ORG
# 15% PERCENT
# just 20 minutes TIME
# CoinGecko PRODUCT
# 1 CARDINAL
# BTC ORG
# around $7,250 MONEY
# two CARDINAL
# HTC Exodus 1 PRODUCT
# Exodus WORK_OF_ART
# 5 CARDINAL
# Bitcoin GPE
# HTC Exodus 5 PRODUCT
# Android-bas GPE
# Indias Supreme Court ORG
# Wednesday DATE
# two-year-old DATE
# The Reserve Bank of India ORG
# April 2018 DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Descartes PERSON
# Brian Brooks PERSON
# first ORDINAL
# the Office of the Comptroller of the Currency ORG
# April 1, 2020 DATE
# Brooks ORG
# OCC ORG
# The South Korean National Assembly ORG
# today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Rousseau PERSON
# Success ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Hegel PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Bentham PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Hannah Arendt PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Marie Curie PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Nightingale ORG
# Success ORG
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Marie Curie PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Stephen Hawking PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Machiavelli PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Baudriallard PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Rousseau PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Aristotle PERSON
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# Bitcoin GPE
# Today DATE
# Satoshi Nakaboto PERSON
# Bitcoin GPE
# the past 24 hours TIME
# Habermass PERSON
# +2731 ORG
# February DATE
# 26 CARDINAL
# 2020 CARDINAL
# 7 min QUANTITY
# IRS ORG
# Reuters
#  ORG
# Thursday DATE
# 6,000 MONEY
# first ORDINAL
# May DATE
# as low as $5,705.31 MONEY
# Bloomberg ORG
# Reuters
#  ORG
# Thursday DATE
# 6,000 MONEY
# first ORDINAL
# May DATE
# as low as $5,705.31 MONEY
# Bloomberg ORG
# Warren Buffett PERSON
# Bitcoin GPE
# BTC ORG
# Monday DATE
# Buffett PERSON
# 7 CARDINAL
# 7 CARDINAL
# one-day DATE
# months DATE
# Bitcoin GPE
# 21 percent PERCENT
# the last 24 hours TIME
# Earlier today TIME
# Bitcoin GPE
# 6,000 MONEY
# first ORDINAL
# Visa ORG
# Google Pay ORG
# Coinbase PRODUCT
# first ORDINAL
# Clifton Collins PERSON
# 49 DATE
# bitcoin GPE
# $60 million MONEY
# PIN ORG
# Collins PERSON
# Taiwan GPE
# today DATE
# $16.75 million MONEY
# SBI Holdings ORG
# Japanese NORP
# Korean NORP
# Bitsonic, Monex Group ORG
# Japan GPE
# American NORP
# this morning TIME
# yesterday DATE
# Asian NORP
# earlier today TIME
# American NORP
# This morning TIME
# US GPE
# 872.42 CARDINAL
# 3.37% PERCENT
# 24,9992.36 CARDINAL
# 500 CARDINAL
# 193.41 CARDINAL
# 6.51% PERCENT
# 2,778.96 CARDINAL
# Nasdaq ORG
# 90.16 CARDINAL
# 6.96% PERCENT
# 1,205.58 CARDINAL
# a desolate week DATE
# the United States GPE
# Monday DATE
# one millionth CARDINAL
# BTC ORG
# one CARDINAL
# Coronavirus ORG
# Microsoft ORG
# Microsoft ORG
# 18 CARDINAL
# more than $10 million MONEY
# Volodymyr Kvashuk PERSON
# Microsoft ORG
# 2016 DATE
# 2018 DATE
# one CARDINAL
# first ORDINAL
# 5 CARDINAL
# HTC 5G Hub PRODUCT
# Android ORG
# 9 CARDINAL
# 4G/5G CARDINAL
# Qualcomms Sn PERSON
# 2020 CARDINAL
# Raspberry Pi PERSON
# Arduino A-Z PERSON
# 74.99 MONEY
# 84% PERCENT
# March 15 DATE
# yesterday DATE
# Russian NORP
# March 13, 2020 DATE
# 1 CARDINAL
# FDA ORG
# AP ORG
# bitcoin GPE
# Treasury ORG
# Thursday DATE
# the World Health Organization ORG
# Trump PERSON
# Europe LOC
# US GPE
# 30 days DATE
# The Bank of Canada ORG
# Wednesday DATE
# morning TIME
# January DATE
# Stephen Poloz PERSON
# Bitcoin PERSON
# China GPE
# Bitcoin GPE
# Bitcoin GPE
# +1582 ORG
# two CARDINAL
# John Gress/ PERSON
# Reuters
#  ORG
# 1 CARDINAL
# bitcoin GPE
# this past week DATE
# 2020 CARDINAL
# DApps &amp ORG
# DLT ORG
# Hundreds of thousands CARDINAL
# last night TIME
# Homea ORG
# 1,200% PERCENT
# Montblanc ORG
# two years ago DATE
# one CARDINAL
# Qualcomm GPE
# 3100 DATE
# Android PERSON
# Warren Buffett PERSON
# Buffett PERSON
# Justin Sun PERSON
# TRON and BitTorrent ORG
# $4.6 million MONEY
# the beginning of March DATE
# Google ORG
# the Play Store WORK_OF_ART
# Bitcoin PERSON
# Thursday DATE
# bitcoin GPE
# 26% PERCENT
# daily DATE
# seven years DATE
# 5,700 MONEY
# Coronavirus Tracker PERSON
# Android ORG
# Bitcoin GPE
# ESET ORG
# DoJ
#  WORK_OF_ART
# Microsoft ORG
# 18 CARDINAL
# $10 million MONEY
# digital ORG
# Seattle GPE
# Micr NORP
# Morgan Stanley ORG
# 2008 DATE
# $13 billion MONEY
# Bitcoin GPE
# over $9,700 MONEY
# Dan Kitwood PERSON
# Between 2011 and 2012 DATE
# Clifton Collins PERSON
# 6,000 CARDINAL
# Bitcoin GPE
# The Irish Times ORG
# Some Libra Association ORG
# Andreessen Horowitz PERSON
# today DATE
# 50 CARDINAL
# The Celo Foundation ORG
# ‘Alliance For Prosperity’ ORG
# US GPE
# USD ORG
# two CARDINAL
# Trading Bitcoin on Coinbase
#  EVENT
# about 21 years ago DATE
# Berkley ORG
# one CARDINAL
# first ORDINAL
# India GPE
# Supreme Court ORG
# Asia LOC
# third ORDINAL
# three CARDINAL
# Rohinton F. Nariman PERSON
# 20 years old DATE
# this month DATE
# 54 CARDINAL
# Bitcoin GPE
# Between 2011 and 2012 DATE
# Dublin GPE
# one CARDINAL
# Clifton Collins PERSON
# Tesla PRODUCT
# Bitcoin GPE
# Verge ORG
# Kickstarter PERSON
# more than half CARDINAL
# thousands CARDINAL
# second ORDINAL
# the Federal Tr ORG
# Facebooks Libra ORG
# Tuesday DATE
# Treasury ORG
# Friday DATE
# Norway GPE
# Japan GPE
# Australia GPE
# Bitcoin GPE
# nearly $8,000 MONEY
# about $5,650 MONEY
# early Thursday DATE
# days DATE
# Thursday DATE
# Matt Stultz PERSON
# Matt PERSON
# Prusa Research ORG
# Czech NORP
# Josef Prusa PERSON
# Matt PERSON
# Matt PERSON
# 20 MONEY
# +9805 ORG
# Techmeme ORG
# 12:00 PM ET TIME
# March  DATE
# Texas GPE
# Bitcoin GPE
# 2020 CARDINAL
# Raspberry Pi PERSON
# Arduino A-Z PERSON
# DIY ORG
# US GPE
# two CARDINAL
# Chinese NORP
# North Korean NORP
# millions of dollars MONEY
# +4323 ORG
# REUTERS/Brian Snyder
# <ul><li ORG
# Fidelity ORG
# Charles Schwab PERSON
# Monday DATE
# morning TIME
# approximately 24 million CARDINAL
# monthly DATE
# December 2019 DATE
# 15 million CARDINAL
# December 2018 DATE
# 7 million CARDINAL
# December 2017 DATE
# Bitcoin GPE
# one CARDINAL
# the Better Business Bureau ORG
# 10 CARDINAL
# 2019 DATE
# BBB ORG
# 5,000 MONEY
# this morning TIME
# Coronavirus ORG
# Nancy Meyerss Modern Love PERSON
# last summer DATE
# Facebook ORG
# Libra GPE
# Subscribe PERSON
# weekly DATE
# weekly DATE
# Steven Seagal PERSON
# Philippe Lopez/AFP PERSON
# Getty Images
#  ORG
# Bitcoin GPE
# just over a decade ago DATE
# Bitcoin PERSON
# December 2017 DATE
# bitcoin GPE
# Opera PERSON
# Bitcoin GPE
# Apple ORG
# Microsoft ORG
# $10m MONEY
# yesterday DATE
# 25 DATE
# mid-2019 DATE
# early 2018 DATE
# Microsoft ORG
# Fraud Investigation Strike Team ORG
# California GPE
# $240m MONEY
# $24m MONEY
# Michael Terpin PERSON
# August 2018 DATE
# Bitcoin GPE
# more than a decade ago DATE
# bitcoin GPE
# Bitcoin GPE
# earlier this year DATE
# Bitcoin GPE
# approximately 50% PERCENT
# Jack Dorsey PERSON
# one CARDINAL
# Silicon ValleyDorsey ORG
# last week DATE
# Elliott Ma PERSON
# Peloton GPE
# Peloton GPE
# Bitcoin GPE
# this week DATE
# one CARDINAL
# 50% PERCENT
# zero CARDINAL
# iPhone ORG
# today DATE
# app ORG

# %% [markdown]
# ---

# %% [markdown]
# ## Ethereum NER

# %%
# Concatenate all of the bitcoin text together
article = ' '.join(ethereum_df['text'])
article
# Out:
# "Bitcoin is going through a remarkably bad day. It turns out all assets are having a rough month including cryptocurrencies. A couple of hours ago, the average price of BTC dropped by 15% in just 20 minutes.\r\nOn CoinGecko, 1 BTC was worth around $7,250 across … [+1146 chars] If a player picks up an item in an online video game, who owns that item? The player, or the company that made the game?\r\nIn most cases, the answer is probably closer to the latter. The item may be in the players digital inventory – but the company can take i… [+2713 chars] Coinbase Card, the Visa debit card that lets you spend cryptocurrency directly from your Coinbase account, now works with Google Pay.\xa0\r\nThis makes Coinbase, a U.S.-based cryptocurrency exchange, the first company that enables users to make mobile payments wit… [+1000 chars] When it comes to celebrities shilling shady initial coin offerings for money, the Securities and Exchange Commission is out for justice.\xa0\r\nActor Steven Seagal found himself on deadly ground on Thursday following an SEC charge that, back in 2018, he failed to … [+2035 chars] The South Korean National Assembly passed new legislation today that will provide a framework for the regulation and legalization of cryptocurrencies and crypto exchanges.\r\nIn a unanimous vote during a special session of the legislature convened amidst the co… [+2878 chars] Orchid\r\nNo matter how much we trust any particular virtual private network to help mask our internet browsing, we engage in that service knowing that all of our data is essentially funneled to a single company, whose servers most of us have never seen with ou… [+5858 chars] To say a lot happened this past week would be is an understatement. It seems that 2020 has no intention of slowing down based on all the recent happenings of the blockchain, DApps &amp; DLT landscapes. Lets take a deep breath and calmly try to go through it a… [+5316 chars] Reuters\r\nBitcoin tanked Thursday and fell below $6,000 for the first time since May amid a larger global market sell-off as investors panic about the spread of coronavirus.\xa0\r\nThe cryptocurrency briefly fell to as low as $5,705.31, according to Bloomberg data.… [+932 chars] Reuters\r\nBitcoin tanked Thursday and fell below $6,000 for the first time since May amid a larger global market sell-off as investors panic about the spread of coronavirus.\xa0\r\nThe cryptocurrency briefly fell to as low as $5,705.31, according to Bloomberg data.… [+932 chars] 7 with 7 posters participating\r\nThe cryptocurrency world has experienced its biggest one-day plunge in months. Bitcoin, the most popular cryptocurrency, is down 21 percent over the last 24 hours. Earlier today, Bitcoin fell below $6,000 for the first time sin… [+1838 chars] Some Libra Association members like Andreessen Horowitz and Coinbase are double-dipping, backing a competing cryptocurrency developer platform. Launching today with over 50 partners, non-profit The Celo Foundation’s ‘Alliance For Prosperity’ offers a way for … [+6101 chars] The author is Camila Russo and the subtitle is How an Army of Crypto-hackers is Building the Next Internet with Ethereum.\xa0 Yes, this is the story of Vitalik Buterin and Ethereum.\xa0 Very useful, and I am glad there is now a good book on this topic.\xa0 Due out Jul… [+28 chars] The world of storage is changing rapidly. We have exciting new technologies such as Intel DC Persistent Memory, along with new applications such as machine learning and blockchain which place new requirements on storage systems. Researchers are working on new… [+7451 chars] February\r\n26, 2020\r\n7 min read\r\nThis story originally appeared on PC MagCryptocurrency is digital currency, or a “digital representation of value,” as the IRS puts it. You can’t see it, hold it in your hand, or put it in your wallet. It’s been in use for over… [+7653 chars] Cryptocurrencies were not immune to the coronavirus-related selloff on Wall Street on Thursday, as the p ...

# %%
# Run the NER processor on all of the text

# Run the NER processor on all of the text
doc = nlp(article)
# Add a title to the document

# %%
# Render the visualization
displacy.render(doc, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is going through a remarkably bad day. It turns out all assets are having a rough month including cryptocurrencies.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     A couple of hours ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# , the average price of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  dropped by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just 20 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# </br>On
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CoinGecko
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BTC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was worth
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around $7,250
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# </br>In most cases, the answer is probably closer to the latter. The item may be in the players digital inventory – but the company can take i… [+2713 chars] Coinbase Card, the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Visa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  debit card that lets you spend cryptocurrency directly from your Coinbase account, now works with
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google Pay
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>This makes
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Coinbase
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# , a U.S.-based cryptocurrency exchange, the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  company that enables users to make mobile payments wit… [+1000 chars] When it comes to celebrities shilling shady initial coin offerings for money,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Securities and Exchange Commission
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Actor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Steven Seagal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  found himself on deadly ground on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  following an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SEC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  charge that, back in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , he failed to … [+2035 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The South Korean National Assembly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  passed new legislation
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>No matter how much we trust any particular virtual private network to help mask our internet browsing, we engage in that service knowing that all of our data is essentially funneled to a single company, whose servers most of us have never seen with ou… [+5858 chars] To say a lot happened
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this past week
#     <span style="font-size: 0.8em;

# %%
# List all Entities
for ent in doc.ents:
    print (ent.text, ent.label_)
# Out:
# Bitcoin GPE
# A couple of hours ago TIME
# BTC ORG
# 15% PERCENT
# just 20 minutes TIME
# CoinGecko PRODUCT
# 1 CARDINAL
# BTC ORG
# around $7,250 MONEY
# Visa ORG
# Google Pay ORG
# Coinbase PRODUCT
# first ORDINAL
# the Securities and Exchange Commission ORG
# Steven Seagal PERSON
# Thursday DATE
# SEC ORG
# 2018 DATE
# The South Korean National Assembly ORG
# today DATE
# this past week DATE
# 2020 CARDINAL
# DApps &amp ORG
# DLT ORG
# Reuters
#  ORG
# Thursday DATE
# 6,000 MONEY
# first ORDINAL
# May DATE
# as low as $5,705.31 MONEY
# Bloomberg ORG
# Reuters
#  ORG
# Thursday DATE
# 6,000 MONEY
# first ORDINAL
# May DATE
# as low as $5,705.31 MONEY
# Bloomberg ORG
# 7 CARDINAL
# 7 CARDINAL
# one-day DATE
# months DATE
# Bitcoin GPE
# 21 percent PERCENT
# the last 24 hours TIME
# Earlier today TIME
# Bitcoin GPE
# 6,000 MONEY
# first ORDINAL
# Some Libra Association ORG
# Andreessen Horowitz PERSON
# today DATE
# 50 CARDINAL
# The Celo Foundation ORG
# ‘Alliance For Prosperity’ ORG
# Camila Russo PERSON
# Building the Next Internet with Ethereum WORK_OF_ART
# Vitalik Buterin and PERSON
# Jul PERSON
# Intel ORG
# February DATE
# 26 CARDINAL
# 2020 CARDINAL
# 7 min QUANTITY
# IRS ORG
# Thursday DATE
# bitcoin GPE
# 26% PERCENT
# daily DATE
# seven years DATE
# 5,700 MONEY
# Hundreds of thousands CARDINAL
# last night TIME
# Homea ORG
# 1,200% PERCENT
# +2024 ORG
# Opera PERSON
# first ORDINAL
# US GPE
# Scandinavian NORP
# Bitcoin GPE
# Apple ORG
# Fatburger PERSON
# AFP ORG
# Getty Images
#  ORG
# Joseph Lubin PERSON
# Co-Founder ORG
# Founder ORG
# Consensys ORG
# Concordia Summit
#  ORG
# Blockchain GPE
# the last few years DATE
